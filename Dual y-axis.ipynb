# %%
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt
import numpy as np

df = data.DataReader("AAPL", 
                       start='2021-01-01', 
                       end='2021-02-01', 
                       data_source='yahoo')
df.head(3)
# Out:
# Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# NumExpr defaulting to 8 threads.
#                   High         Low        Open       Close     Volume  \
# Date
# 2020-12-31  134.740005  131.720001  134.080002  132.690002   99116600
# 2021-01-04  133.610001  126.760002  133.520004  129.410004  143301900
# 2021-01-05  131.740005  128.429993  128.889999  131.009995   97664900
#
#              Adj Close
# Date
# 2020-12-31  131.709198
# 2021-01-04  128.453461
# 2021-01-05  130.041626

# %%
df.iloc[:,[0:4,5]].head(3)
# Out:
#   File "C:\Users\Vitali\AppData\Local\Temp/ipykernel_16884/2944441954.py", line 1
#     df.iloc[:,[0:4,5]].head(3)
#                 ^
# SyntaxError: invalid syntax

# %%
df.iloc[:,np.r_[0:4,5]].head(3)
# Out:
#                   High         Low        Open       Close   Adj Close
# Date
# 2020-12-31  134.740005  131.720001  134.080002  132.690002  131.709198
# 2021-01-04  133.610001  126.760002  133.520004  129.410004  128.453461
# 2021-01-05  131.740005  128.429993  128.889999  131.009995  130.041626

# %%
df.iloc[:,4].head(3)
# Out:
# Date
# 2020-12-31     99116600
# 2021-01-04    143301900
# 2021-01-05     97664900
# Name: Volume, dtype: int64

# %%
fig, ax1 = plt.subplots(figsize=(12,8))

ax1.set_xlabel('Time')
ax1.set_ylabel('Stock Price',color='red')
ax1.plot(df.iloc[:,np.r_[0:4,5]],linestyle='dotted')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'maroon'
ax2.set_ylabel('Volume', color=color)  # we already handled the x-label with ax1
ax2.plot(df.iloc[:,4], color=color, linewidth=4)
ax2.tick_params(axis='y', labelcolor=color)

#fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
